# %% [markdown]
# # **Simple Linear Regression**

# %%
# import packages
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# download and prepare data
data_root = 'https://github.com/ageron/data/raw/main/'
lifesat = pd.read_csv(data_root + "lifesat/lifesat.csv")
X = lifesat[["GDP per capita (USD)"]].values
y = lifesat[["Life satisfaction"]].values

# select a linear model
model = LinearRegression()

# train the model
model.fit(X,y)

# make a prediction for Cyprus
X_new = [[37_655.2]] # Cyprus GDP per capita in 2020
prediction = model.predict(X_new)
print('Life satisfaction prediction for Cypriots using Simple Linear Regression: ',prediction,'\n')

# visualize the data
lifesat.plot(kind='scatter', grid=True,
             x="GDP per capita (USD)", y="Life satisfaction")
plt.axis([23_500, 62_500, 4, 9])
plt.title('Life satisfaction vs GDP per capita in 2020, OECD')
plt.show()
# Out:
# Life satisfaction prediction for Cypriots using Simple Linear Regression:  [[6.30165767]]

# %% [markdown]
# # **KNN Regresion**

# %%
# import package
from sklearn.neighbors import KNeighborsRegressor

# select a KNN regressor
knn_model = KNeighborsRegressor(n_neighbors=3) # k = 3: Israel, Lithuania, Slovenia

# train the model
knn_model.fit(X,y)

# make a prediction for Cyprus
X_new = [[37_655.2]] # Cyprus GDP per capita in 2020
prediction = model.predict(X_new)
print('Life satisfaction prediction for Cypriots using KNN: ',prediction)
# Out:
# Life satisfaction prediction for Cypriots using KNN:  [[6.33333333]]

# %% [markdown]
# ---------
#
# ## **Summary of Machine Learning Project**
#
# 1.   Studied the data
# 2.   Selected a model
# 3.   Trained the model on the data (the machine learning algorithm searched for the optimal thetas that minimize the cost function)
# 4.   Applied the model to make predictions on new cases (inference), and generalises reasonably
